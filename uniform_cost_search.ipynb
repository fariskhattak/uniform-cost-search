# %%
# uniform cost function
# returns the minimum cost and the path with minimum cost
def  uniform_cost_search(start, goal, graph, cost):
    answer = {node: {'cost': float('inf'), 'path': []} for node in goal}
#     **************************************
#     ******** Write your code here ********
#     **************************************
    pq = [(0, start, [start])]
    
    visited = {}

    goals_set = set(goal)

    while pq:
        pq.sort(key=lambda x: x[0])
        current_cost, node, path = pq.pop(0)

        if node in visited and current_cost > visited[node]:
            continue

        visited[node] = current_cost

        if node in goals_set and current_cost < answer[node]['cost']:
            answer[node] = {'cost': current_cost, 'path': path}

        for neighbor in graph[node]:
            new_cost = current_cost + cost.get((node, neighbor), float('inf'))
            if neighbor not in visited or new_cost < visited[neighbor]:
                pq.append((new_cost, neighbor, path + [neighbor]))
    
    return answer
 
# main function
if __name__ == '__main__':
     
    # create a graph with no more than 30 nodes
    graph, cost = [[] for i in range(30)], {}

    print(graph)
 
    # add edges to the graph
    graph[0].append(4)
    graph[0].append(5)
    graph[0].append(16)
    graph[2].append(1)
    graph[3].append(1)
    graph[4].append(2)
    graph[4].append(3)
    graph[4].append(5)
    graph[5].append(8)
    graph[5].append(18)
    graph[6].append(3)
    graph[6].append(7)
    graph[8].append(16)
    graph[8].append(17)
    graph[16].append(17)
    graph[18].append(6)
    
 
    # add cost to each edge
    cost[(0, 4)] = 3
    cost[(0, 5)] = 9
    cost[(0, 16)] = 1
    cost[(2, 1)] = 2
    cost[(3, 1)] = 2
    cost[(4, 2)] = 1
    cost[(4, 3)] = 8
    cost[(4, 5)] = 2
    cost[(5, 8)] = 3
    cost[(5, 18)] = 2
    cost[(6, 3)] = 3
    cost[(6, 7)] = 2
    cost[(8, 16)] = 4
    cost[(8, 17)] = 4
    cost[(16, 17)] = 15
    cost[(18, 6)] = 1

    print(graph)
    
    # set start state 
    start = 0
    
    # set goal state, there can be multiple goal states
    goal = [7]
    
    # call uniform_search_cost function to get the minimum cost to reach the goal and the path with minumum cost
    # ****** You have to implement this function *****
    min_cost_info = uniform_cost_search(start, goal, graph, cost)

    for node, info in min_cost_info.items():
        print(f'Minimum cost from {start} to {node} is {info["cost"]}')
        print(f'Path: {info["path"]}')
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[4, 5, 16], [], [1], [1], [2, 3, 5], [8, 18], [3, 7], [], [16, 17], [], [], [], [], [], [], [], [17], [], [6], [], [], [], [], [], [], [], [], [], [], []]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 88
#      84 goal = [7]
#      86 # call uniform_search_cost function to get the minimum cost to reach the goal and the path with minumum cost
#      87 # ****** You have to implement this function *****
# ---> 88 min_cost_info = uniform_cost_search(start, goal, graph, cost)
#      90 for node, info in min_cost_info.items():
#      91     print(f'Minimum cost from {start} to {node} is {info["cost"]}')
#
# Cell In[6], line 29, in uniform_cost_search(start, goal, graph, cost)
#      27         new_cost = current_cost + cost.get((node, neighbor), float('inf'))
#      28         if neighbor not in visited or new_cost < visited[neighbor]:
# ---> 29             pq.append(new_cost, neighbor, path + [neighbor])
#      31 return answer
#
# TypeError: list.append() takes exactly one argument (3 given)
